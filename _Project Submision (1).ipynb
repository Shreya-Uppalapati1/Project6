# %% [markdown]
# # VIPAINE - Project 6

# %% [markdown]
# # READING THE LIBARIES

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # IMPORTING DATA

# %%
brics=pd.read_csv('brics.csv')

# %%
brics.head()
# Out:
#   code       country  population      area    capital
# 0   BR        Brazil         200   8515767   Brasilia
# 1   RU        Russia         144  17098242     Moscow
# 2   IN         India        1252   3287590  New Delhi
# 3   CH         China        1357   9596961    Beijing
# 4   SA  South Africa          55   1221037   Pretoria

# %%
print(type(5))
print(type('a text'))
print(type(True))
print(type(brics))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'bool'>
# <class 'pandas.core.frame.DataFrame'>

# %%
brics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   code        5 non-null      object
#  1   country     5 non-null      object
#  2   population  5 non-null      int64
#  3   area        5 non-null      int64
#  4   capital     5 non-null      object
# dtypes: int64(2), object(3)
# memory usage: 328.0+ bytes

# %% [markdown]
# There are five columns of which three are categorial in nature and one is numerical.

# %%
brics.value_counts()
# Out:
# code  country       population  area      capital
# BR    Brazil        200         8515767   Brasilia     1
# CH    China         1357        9596961   Beijing      1
# IN    India         1252        3287590   New Delhi    1
# RU    Russia        144         17098242  Moscow       1
# SA    South Africa  55          1221037   Pretoria     1
# dtype: int64

# %% [markdown]
# There are 200 people in Brazil,1357 people in China, 1252 people in India, 144 people in Russia and 55 people from South Africa

# %%
brics.sort_values(by=['code'])
# Out:
#   code       country  population      area    capital
# 0   BR        Brazil         200   8515767   Brasilia
# 3   CH         China        1357   9596961    Beijing
# 2   IN         India        1252   3287590  New Delhi
# 1   RU        Russia         144  17098242     Moscow
# 4   SA  South Africa          55   1221037   Pretoria

# %%
brics.sort_values(by=['code'], ascending = False)
#Descending
# Out:
#   code       country  population      area    capital
# 4   SA  South Africa          55   1221037   Pretoria
# 1   RU        Russia         144  17098242     Moscow
# 2   IN         India        1252   3287590  New Delhi
# 3   CH         China        1357   9596961    Beijing
# 0   BR        Brazil         200   8515767   Brasilia

# %%
# TO DO: Try printing the dataframe once using print() and once without print(). Do you observe any difference?

# %%
print(brics)
# Out:
#   code       country  population      area    capital
# 0   BR        Brazil         200   8515767   Brasilia
# 1   RU        Russia         144  17098242     Moscow
# 2   IN         India        1252   3287590  New Delhi
# 3   CH         China        1357   9596961    Beijing
# 4   SA  South Africa          55   1221037   Pretoria

# %%
brics.head()
# Out:
#   code       country  population      area    capital
# 0   BR        Brazil         200   8515767   Brasilia
# 1   RU        Russia         144  17098242     Moscow
# 2   IN         India        1252   3287590  New Delhi
# 3   CH         China        1357   9596961    Beijing
# 4   SA  South Africa          55   1221037   Pretoria

# %% [markdown]
# ### TO DO: Do you think sorting the data changes the data in original dataframe?
# ### print the dataframe and observe the output to get the answer.

# %% [markdown]
# Sorting data has no impact on data itself as the values are not changed.

# %% [markdown]
# # TO DO: Sort the data to see which country has largest population ( population is in millions).

# %%
brics.sort_values(by='population',ascending=False)#China has the largest population
# Out:
#   code       country  population      area    capital
# 3   CH         China        1357   9596961    Beijing
# 2   IN         India        1252   3287590  New Delhi
# 0   BR        Brazil         200   8515767   Brasilia
# 1   RU        Russia         144  17098242     Moscow
# 4   SA  South Africa          55   1221037   Pretoria

# %% [markdown]
# # TO DO: Sort the data to see which country is smallest in size.

# %%
brics.sort_values(by='area')
# Out:
#   code       country  population      area    capital
# 4   SA  South Africa          55   1221037   Pretoria
# 2   IN         India        1252   3287590  New Delhi
# 0   BR        Brazil         200   8515767   Brasilia
# 3   CH         China        1357   9596961    Beijing
# 1   RU        Russia         144  17098242     Moscow

# %% [markdown]
# South Africa has the smallest Area

# %%
brics.country.sort_values(ascending=False)
# Out:
# 4    South Africa
# 1          Russia
# 2           India
# 3           China
# 0          Brazil
# Name: country, dtype: object

# %% [markdown]
# # TO DO: Sort and print area column on from largest to smallest.

# %%
brics.sort_values(by='area',ascending=False)
# Out:
#   code       country  population      area    capital
# 1   RU        Russia         144  17098242     Moscow
# 3   CH         China        1357   9596961    Beijing
# 0   BR        Brazil         200   8515767   Brasilia
# 2   IN         India        1252   3287590  New Delhi
# 4   SA  South Africa          55   1221037   Pretoria

# %% [markdown]
# Russia has the largest area among these countries followed by China,Brazil,India and then South Africa

# %%
print(brics["country"])
# Out:
# 0          Brazil
# 1          Russia
# 2           India
# 3           China
# 4    South Africa
# Name: country, dtype: object

# %% [markdown]
# # TO DO: Print area column from brics dataframe

# %%
brics['area']
# Out:
# 0     8515767
# 1    17098242
# 2     3287590
# 3     9596961
# 4     1221037
# Name: area, dtype: int64

# %%
brics[['code']]
# Out:
#   code
# 0   BR
# 1   RU
# 2   IN
# 3   CH
# 4   SA

# %%
print(brics["area"])
# Out:
# 0     8515767
# 1    17098242
# 2     3287590
# 3     9596961
# 4     1221037
# Name: area, dtype: int64

# %% [markdown]
# # TO DO:  Print code column from the dataframe using dot

# %%
brics.code
# Out:
# 0    BR
# 1    RU
# 2    IN
# 3    CH
# 4    SA
# Name: code, dtype: object

# %% [markdown]
# # TO DO: Print country, capital and population

# %%
brics[['country','capital','population']]
# Out:
#         country    capital  population
# 0        Brazil   Brasilia         200
# 1        Russia     Moscow         144
# 2         India  New Delhi        1252
# 3         China    Beijing        1357
# 4  South Africa   Pretoria          55

# %% [markdown]
# # TO DO: Use .iloc to print the values from all columns from 3rd row (index number will be 1 less than the row number).

# %%
brics.iloc[2]
# Out:
# code                 IN
# country           India
# population         1252
# area            3287590
# capital       New Delhi
# Name: 2, dtype: object

# %%
brics
# Out:
#   code       country  population      area    capital
# 0   BR        Brazil         200   8515767   Brasilia
# 1   RU        Russia         144  17098242     Moscow
# 2   IN         India        1252   3287590  New Delhi
# 3   CH         China        1357   9596961    Beijing
# 4   SA  South Africa          55   1221037   Pretoria

# %%
brics = pd.read_csv("brics.csv",index_col=0)

# %%
brics
# Out:
#            country  population      area    capital
# code
# BR          Brazil         200   8515767   Brasilia
# RU          Russia         144  17098242     Moscow
# IN           India        1252   3287590  New Delhi
# CH           China        1357   9596961    Beijing
# SA    South Africa          55   1221037   Pretoria

# %% [markdown]
# # TO DO: Use .loc to print the values from all columns for IN

# %%
brics.loc['IN']
# Out:
# country           India
# population         1252
# area            3287590
# capital       New Delhi
# Name: IN, dtype: object

# %%
brics
# Out:
#            country  population      area    capital
# code
# BR          Brazil         200   8515767   Brasilia
# RU          Russia         144  17098242     Moscow
# IN           India        1252   3287590  New Delhi
# CH           China        1357   9596961    Beijing
# SA    South Africa          55   1221037   Pretoria

# %%
brics["on_earth"] = [True, True, True, True, True]  
brics
# Out:
#            country  population      area    capital  on_earth
# code
# BR          Brazil         200   8515767   Brasilia      True
# RU          Russia         144  17098242     Moscow      True
# IN           India        1252   3287590  New Delhi      True
# CH           China        1357   9596961    Beijing      True
# SA    South Africa          55   1221037   Pretoria      True

# %%
brics["density"] = brics["population"] / brics["area"] * 1000000   # per km sq.
brics
# Out:
#            country  population      area    capital  on_earth     density
# code
# BR          Brazil         200   8515767   Brasilia      True   23.485847
# RU          Russia         144  17098242     Moscow      True    8.421918
# IN           India        1252   3287590  New Delhi      True  380.826076
# CH           China        1357   9596961    Beijing      True  141.398928
# SA    South Africa          55   1221037   Pretoria      True   45.043680

# %%
brics.style.set_precision(2)
# Out:
# <style  type="text/css" >
# </style><table id="T_0fcd3_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >country</th>        <th class="col_heading level0 col1" >population</th>        <th class="col_heading level0 col2" >area</th>        <th class="col_heading level0 col3" >capital</th>        <th class="col_heading level0 col4" >on_earth</th>        <th class="col_heading level0 col5" >density</th>    </tr>    <tr>        <th class="index_name level0" >code</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_0fcd3_level0_row0" class="row_heading level0 row0" >BR</th>
#                         <td id="T_0fcd3_row0_col0" class="data row0 col0" >Brazil</td>
#                         <td id="T_0fcd3_row0_col1" class="data row0 col1" >200</td>
#                         <td id="T_0fcd3_row0_col2" class="data row0 col2" >8515767</td>
#                         <td id="T_0fcd3_row0_col3" class="data row0 col3" >Brasilia</td>
#                         <td id="T_0fcd3_row0_col4" class="data row0 col4" >True</td>
#                         <td id="T_0fcd3_row0_col5" class="data row0 col5" >23.49</td>
#             </tr>
#             <tr>
#                         <th id="T_0fcd3_level0_row1" class="row_heading level0 row1" >RU</th>
#                         <td id="T_0fcd3_row1_col0" class="data row1 col0" >Russia</td>
#                         <td id="T_0fcd3_row1_col1" class="data row1 col1" >144</td>
#                         <td id="T_0fcd3_row1_col2" class="data row1 col2" >17098242</td>
#                         <td id="T_0fcd3_row1_col3" class="data row1 col3" >Moscow</td>
#                         <td id="T_0fcd3_row1_col4" class="data row1 col4" >True</td>
#                         <td id="T_0fcd3_row1_col5" class="data row1 col5" >8.42</td>
#             </tr>
#             <tr>
#                         <th id="T_0fcd3_level0_row2" class="row_heading level0 row2" >IN</th>
#                         <td id="T_0fcd3_row2_col0" class="data row2 col0" >India</td>
#                         <td id="T_0fcd3_row2_col1" class="data row2 col1" >1252</td>
#                         <td id="T_0fcd3_row2_col2" class="data row2 col2" >3287590</td>
#                         <td id="T_0fcd3_row2_col3" class="data row2 col3" >New Delhi</td>
#                         <td id="T_0fcd3_row2_col4" class="data row2 col4" >True</td>
#                         <td id="T_0fcd3_row2_col5" class="data row2 col5" >380.83</td>
#             </tr>
#             <tr>
#                         <th id="T_0fcd3_level0_row3" class="row_heading level0 row3" >CH</th>
#                         <td id="T_0fcd3_row3_col0" class="data row3 col0" >China</td>
#                         <td id="T_0fcd3_row3_col1" class="data row3 col1" >1357</td>
#                         <td id="T_0fcd3_row3_col2" class="data row3 col2" >9596961</td>
#                         <td id="T_0fcd3_row3_col3" class="data row3 col3" >Beijing</td>
#                         <td id="T_0fcd3_row3_col4" class="data row3 col4" >True</td>
#                         <td id="T_0fcd3_row3_col5" class="data row3 col5" >141.40</td>
#             </tr>
#             <tr>
#                         <th id="T_0fcd3_level0_row4" class="row_heading level0 row4" >SA</th>
#                         <td id="T_0fcd3_row4_col0" class="data row4 col0" >South Africa</td>
#                         <td id="T_0fcd3_row4_col1" class="data row4 col1" >55</td>
#                         <td id="T_0fcd3_row4_col2" class="data row4 col2" >1221037</td>
#                         <td id="T_0fcd3_row4_col3" class="data row4 col3" >Pretoria</td>
#                         <td id="T_0fcd3_row4_col4" class="data row4 col4" >True</td>
#                         <td id="T_0fcd3_row4_col5" class="data row4 col5" >45.04</td>
#             </tr>
#     </tbody></table>

# %%
brics["density"].round(2)
# Out:
# code
# BR     23.49
# RU      8.42
# IN    380.83
# CH    141.40
# SA     45.04
# Name: density, dtype: float64

# %%
newrow = {'code':'WK', 'country':'Wakanda', 'population':5,'area':1000000,'capital':'Wakanda City','on_earth':False,'density':5}
brics1 = brics.append(newrow,ignore_index=True)

# %%
brics.loc['WK'] = ['Wakanda', 5, 1000000, 'Wakanda City', False, 5]   
# Sequence is very important. Data types may get changed due to wrong sequence.
brics
# Out:
#            country  population      area       capital  on_earth     density
# code
# BR          Brazil         200   8515767      Brasilia      True   23.485847
# RU          Russia         144  17098242        Moscow      True    8.421918
# IN           India        1252   3287590     New Delhi      True  380.826076
# CH           China        1357   9596961       Beijing      True  141.398928
# SA    South Africa          55   1221037      Pretoria      True   45.043680
# WK         Wakanda           5   1000000  Wakanda City     False    5.000000

# %% [markdown]
# # TO DO: Add a new row in the dataframe using .loc any other country with some values in all columns.

# %%
brics.loc['QA'] = ['Qatar', 20, 1400000, 'Doha', True, 6]   
brics
# Out:
#            country  population      area       capital  on_earth     density
# code
# BR          Brazil         200   8515767      Brasilia      True   23.485847
# RU          Russia         144  17098242        Moscow      True    8.421918
# IN           India        1252   3287590     New Delhi      True  380.826076
# CH           China        1357   9596961       Beijing      True  141.398928
# SA    South Africa          55   1221037      Pretoria      True   45.043680
# WK         Wakanda           5   1000000  Wakanda City     False    5.000000
# QA           Qatar          20   1400000          Doha      True    6.000000

# %%
brics
# Out:
#            country  population      area       capital  on_earth     density
# code
# BR          Brazil         200   8515767      Brasilia      True   23.485847
# RU          Russia         144  17098242        Moscow      True    8.421918
# IN           India        1252   3287590     New Delhi      True  380.826076
# CH           China        1357   9596961       Beijing      True  141.398928
# SA    South Africa          55   1221037      Pretoria      True   45.043680
# WK         Wakanda           5   1000000  Wakanda City     False    5.000000
# QA           Qatar          20   1400000          Doha      True    6.000000

# %%
brics
# Out:
#            country  population      area       capital  on_earth     density
# code
# BR          Brazil         200   8515767      Brasilia      True   23.485847
# RU          Russia         144  17098242        Moscow      True    8.421918
# IN           India        1252   3287590     New Delhi      True  380.826076
# CH           China        1357   9596961       Beijing      True  141.398928
# SA    South Africa          55   1221037      Pretoria      True   45.043680
# WK         Wakanda           5   1000000  Wakanda City     False    5.000000
# QA           Qatar          20   1400000          Doha      True    6.000000

# %%
brics.loc["IN","capital"]
# Out:
# 'New Delhi'

# %%
brics["capital"].loc["IN"]
# Out:
# 'New Delhi'

# %%
brics.loc["IN"]['capital']
# Out:
# 'New Delhi'

# %%
brics1 = brics
brics1
# Out:
#            country  population      area       capital  on_earth     density
# code
# BR          Brazil         200   8515767      Brasilia      True   23.485847
# RU          Russia         144  17098242        Moscow      True    8.421918
# IN           India        1252   3287590     New Delhi      True  380.826076
# CH           China        1357   9596961       Beijing      True  141.398928
# SA    South Africa          55   1221037      Pretoria      True   45.043680
# WK         Wakanda           5   1000000  Wakanda City     False    5.000000
# QA           Qatar          20   1400000          Doha      True    6.000000

# %%
brics1.drop(['area'], axis=1)  # axis = 0 by default for rows. Axis = 1 for column.

# For multiple columns, mention the columns separated by comma. Ex. df.drop(['name','max'], axis=1)
# Out:
#            country  population       capital  on_earth     density
# code
# BR          Brazil         200      Brasilia      True   23.485847
# RU          Russia         144        Moscow      True    8.421918
# IN           India        1252     New Delhi      True  380.826076
# CH           China        1357       Beijing      True  141.398928
# SA    South Africa          55      Pretoria      True   45.043680
# WK         Wakanda           5  Wakanda City     False    5.000000
# QA           Qatar          20          Doha      True    6.000000

# %%
brics1=brics

# %% [markdown]
# # TO DO: Try deleting area and density columns from brics1 dataframe

# %%
brics1.drop(['area','density'], axis=1)
# Out:
#            country  population       capital  on_earth
# code
# BR          Brazil         200      Brasilia      True
# RU          Russia         144        Moscow      True
# IN           India        1252     New Delhi      True
# CH           China        1357       Beijing      True
# SA    South Africa          55      Pretoria      True
# WK         Wakanda           5  Wakanda City     False
# QA           Qatar          20          Doha      True

# %%
brics1=brics

# %% [markdown]
# # TO DO: Delete the record for Wakanda by using its index WK
# # Hint: Use WK as identifier and delete axis argument or put axis = 0

# %%
brics1.drop(['WK'],axis=0)
# Out:
#            country  population      area    capital  on_earth     density
# code
# BR          Brazil         200   8515767   Brasilia      True   23.485847
# RU          Russia         144  17098242     Moscow      True    8.421918
# IN           India        1252   3287590  New Delhi      True  380.826076
# CH           China        1357   9596961    Beijing      True  141.398928
# SA    South Africa          55   1221037   Pretoria      True   45.043680
# QA           Qatar          20   1400000       Doha      True    6.000000

# %%
cars=pd.read_csv('cars.csv')

# %%
cars.head()
# Out:
#   Unnamed: 0  cars_per_cap        country  drives_right
# 0         US           809  United States          True
# 1        AUS           731      Australia         False
# 2        JAP           588          Japan         False
# 3         IN            18          India         False
# 4         RU           200         Russia          True

# %% [markdown]
# # TO DO: Print top 7 rows from the data
# # To print n number of rows, enter the value of n in the head() as an argument.

# %%
cars.head(7)
# Out:
#   Unnamed: 0  cars_per_cap        country  drives_right
# 0         US           809  United States          True
# 1        AUS           731      Australia         False
# 2        JAP           588          Japan         False
# 3         IN            18          India         False
# 4         RU           200         Russia          True
# 5        MOR            70        Morocco          True
# 6         EG            45          Egypt          True

# %%
cars.tail()
# Out:
#   Unnamed: 0  cars_per_cap  country  drives_right
# 2        JAP           588    Japan         False
# 3         IN            18    India         False
# 4         RU           200   Russia          True
# 5        MOR            70  Morocco          True
# 6         EG            45    Egypt          True

# %% [markdown]
# # TO DO: Print last 10 rows from the dataframe

# %%
cars.tail(10)
# Out:
#   Unnamed: 0  cars_per_cap        country  drives_right
# 0         US           809  United States          True
# 1        AUS           731      Australia         False
# 2        JAP           588          Japan         False
# 3         IN            18          India         False
# 4         RU           200         Russia          True
# 5        MOR            70        Morocco          True
# 6         EG            45          Egypt          True

# %% [markdown]
# # TO DO: Read the data again and set the 1st column as the index column. Then, print the cars dataframe.

# %%
print(cars)

df1 = cars.rename( columns={'Unnamed: 0':'code'}, inplace=False ) 
cars.rename( columns={'Unnamed: 0':'code'}, inplace=True ) 

print(df1)
print(cars)      # With False, there will be no change in cars dataframe.
# Out:
#   Unnamed: 0  cars_per_cap        country  drives_right
# 0         US           809  United States          True
# 1        AUS           731      Australia         False
# 2        JAP           588          Japan         False
# 3         IN            18          India         False
# 4         RU           200         Russia          True
# 5        MOR            70        Morocco          True
# 6         EG            45          Egypt          True
#   code  cars_per_cap        country  drives_right
# 0   US           809  United States          True
# 1  AUS           731      Australia         False
# 2  JAP           588          Japan         False
# 3   IN            18          India         False
# 4   RU           200         Russia          True
# 5  MOR            70        Morocco          True
# 6   EG            45          Egypt          True
#   code  cars_per_cap        country  drives_right
# 0   US           809  United States          True
# 1  AUS           731      Australia         False
# 2  JAP           588          Japan         False
# 3   IN            18          India         False
# 4   RU           200         Russia          True
# 5  MOR            70        Morocco          True
# 6   EG            45          Egypt          True

# %%
print(cars['cars_per_cap'])  # without column name at the top. Prints data and detail
# Out:
# 0    809
# 1    731
# 2    588
# 3     18
# 4    200
# 5     70
# 6     45
# Name: cars_per_cap, dtype: int64

# %%
print(cars[['cars_per_cap']])  # print the actual data
# Out:
#    cars_per_cap
# 0           809
# 1           731
# 2           588
# 3            18
# 4           200
# 5            70
# 6            45

# %%
cars.head()
# Out:
#   code  cars_per_cap        country  drives_right
# 0   US           809  United States          True
# 1  AUS           731      Australia         False
# 2  JAP           588          Japan         False
# 3   IN            18          India         False
# 4   RU           200         Russia          True

# %%
cars = pd.read_csv("cars.csv",index_col=0)

# %%
print(cars)
# Out:
#      cars_per_cap        country  drives_right
# US            809  United States          True
# AUS           731      Australia         False
# JAP           588          Japan         False
# IN             18          India         False
# RU            200         Russia          True
# MOR            70        Morocco          True
# EG             45          Egypt          True

# %% [markdown]
# # TO DO : Print the details of RU
# # Hint: You should use either .loc or .iloc (just one is correct).

# %%
cars.loc['RU']
# Out:
# cars_per_cap       200
# country         Russia
# drives_right      True
# Name: RU, dtype: object

# %% [markdown]
# # TO DO: Print all details for RU and AUS from cars dataframe.

# %%
cars.loc[['RU','AUS']]
# Out:
#      cars_per_cap    country  drives_right
# RU            200     Russia          True
# AUS           731  Australia         False

# %%
cars.loc['IN'][0]
# Out:
# 18

# %%
cars.loc['RU'][0]
# Out:
# 200

# %%
x=cars[3:5]

# %%
x
# Out:
#     cars_per_cap country  drives_right
# IN            18   India         False
# RU           200  Russia          True

# %%
x['cars_per_cap']
# Out:
# IN     18
# RU    200
# Name: cars_per_cap, dtype: int64

# %%
x[['cars_per_cap','country']]
# Out:
#     cars_per_cap country
# IN            18   India
# RU           200  Russia

# %%
marks=pd.read_csv('marks.csv')

# %%
marks.head()
# Out:
#   Student_ID Student_Name    English      Maths    Science    History  \
# 0        S01        Alice  96.874050  15.367999  58.682033  59.690510
# 1        S02          Bob   5.462131  81.032680  83.171957  45.664012
# 2        S03      Charlie  60.753099  65.219548  99.323628  24.281512
# 3        S04        David  21.160844  95.052971  35.860852  62.865185
# 4        S05       Edward  63.250994  60.693247   7.020915  60.505272
#
#    Social_Studies
# 0       61.373070
# 1       80.805730
# 2       58.057612
# 3       95.264572
# 4       34.041671

# %% [markdown]
# # TO DO: Show the shape of the dataframe
# # Hint: shape()

# %%
marks.shape
# Out:
# (20, 7)

# %% [markdown]
# There are 20 rows and 7 columns

# %% [markdown]
# # TO DO: Get the information and structure of the data with non-null value counts

# %%
marks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Student_ID      20 non-null     object
#  1   Student_Name    20 non-null     object
#  2   English         20 non-null     float64
#  3   Maths           20 non-null     float64
#  4   Science         20 non-null     float64
#  5   History         20 non-null     float64
#  6   Social_Studies  20 non-null     float64
# dtypes: float64(5), object(2)
# memory usage: 1.2+ KB

# %%
marks.describe()
# Out:
#          English      Maths    Science    History  Social_Studies
# count  20.000000  20.000000  20.000000  20.000000       20.000000
# mean   41.353760  52.261151  40.535968  46.216759       62.332907
# std    29.789723  31.312389  33.586432  22.880634       28.580326
# min     5.302984   7.160086   2.618987   7.462064        7.305670
# 25%    15.606560  22.897319  14.145783  31.408678       34.347250
# 50%    40.457156  55.994143  34.207956  46.335594       74.529222
# 75%    64.007402  79.889304  64.804514  61.095250       83.320148
# max    96.874050  99.270852  99.323628  80.925749       95.264572

# %%
marks.dtypes
# Out:
# Student_ID         object
# Student_Name       object
# English           float64
# Maths             float64
# Science           float64
# History           float64
# Social_Studies    float64
# dtype: object

# %%
print(type(marks))
print(type(marks.English))  # Column's dtype is Series, the dtype of the values is Object.
print(type(5))
print(type(5.5))
print(type("Python"))
print(type(True))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.series.Series'>
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %%
print(marks)
display(marks) 
marks
# Out:
#    Student_ID Student_Name    English      Maths    Science    History  \
# 0         S01        Alice  96.874050  15.367999  58.682033  59.690510
# 1         S02          Bob   5.462131  81.032680  83.171957  45.664012
# 2         S03      Charlie  60.753099  65.219548  99.323628  24.281512
# 3         S04        David  21.160844  95.052971  35.860852  62.865185
# 4         S05       Edward  63.250994  60.693247   7.020915  60.505272
# 5         S06        Fysal  42.694748  77.348295  37.216613  33.784399
# 6         S07       George  66.276626  46.812190  14.219533  18.582771
# 7         S08       Hareez   5.302984  11.966929  43.980951  54.410098
# 8         S09         Ivan   5.777530  79.508179  94.559212  38.355867
# 9         S10         John  30.968731  14.282925   3.312853  79.916094
# 10        S11       Kelvin  40.219985  55.325651  16.826141   7.462064
# 11        S12          Lia  95.928421  35.789430  95.440164  43.520213
# 12        S13        Maria   8.215446  25.042783  16.518147  36.543154
# 13        S14         Noel  72.833673   7.160086  22.089014  52.867757
# 14        S15       Oliver   5.982402  16.460926  40.977224  80.925749
# 15        S16        Peter  40.694327  91.395888   8.149884  13.852098
# 16        S17          Roy  43.559963  99.270852  13.924531  71.306738
# 17        S18          Ria  30.830802  25.545682  84.271650  78.727155
# 18        S19        Suvin  72.218179  85.284128  32.555060  47.007177
# 19        S20          Tan  18.070264  56.662635   2.618987  14.067349
#
#     Social_Studies
# 0        61.373070
# 1        80.805730
# 2        58.057612
# 3        95.264572
# 4        34.041671
# 5        85.019761
# 6        87.021849
# 7        74.530018
# 8        90.483635
# 9        32.706891
# 10       34.449110
# 11       71.930382
# 12       80.665074
# 13       20.583259
# 14       83.312063
# 15       74.528425
# 16        8.432155
# 17        7.305670
# 18       83.344403
# 19       82.802787
#    Student_ID Student_Name    English      Maths    Science    History  \
# 0         S01        Alice  96.874050  15.367999  58.682033  59.690510
# 1         S02          Bob   5.462131  81.032680  83.171957  45.664012
# 2         S03      Charlie  60.753099  65.219548  99.323628  24.281512
# 3         S04        David  21.160844  95.052971  35.860852  62.865185
# 4         S05       Edward  63.250994  60.693247   7.020915  60.505272
# 5         S06        Fysal  42.694748  77.348295  37.216613  33.784399
# 6         S07       George  66.276626  46.812190  14.219533  18.582771
# 7         S08       Hareez   5.302984  11.966929  43.980951  54.410098
# 8         S09         Ivan   5.777530  79.508179  94.559212  38.355867
# 9         S10         John  30.968731  14.282925   3.312853  79.916094
# 10        S11       Kelvin  40.219985  55.325651  16.826141   7.462064
# 11        S12          Lia  95.928421  35.789430  95.440164  43.520213
# 12        S13        Maria   8.215446  25.042783  16.518147  36.543154
# 13        S14         Noel  72.833673   7.160086  22.089014  52.867757
# 14        S15       Oliver   5.982402  16.460926  40.977224  80.925749
# 15        S16        Peter  40.694327  91.395888   8.149884  13.852098
# 16        S17          Roy  43.559963  99.270852  13.924531  71.306738
# 17        S18          Ria  30.830802  25.545682  84.271650  78.727155
# 18        S19        Suvin  72.218179  85.284128  32.555060  47.007177
# 19        S20          Tan  18.070264  56.662635   2.618987  14.067349
#
#     Social_Studies
# 0        61.373070
# 1        80.805730
# 2        58.057612
# 3        95.264572
# 4        34.041671
# 5        85.019761
# 6        87.021849
# 7        74.530018
# 8        90.483635
# 9        32.706891
# 10       34.449110
# 11       71.930382
# 12       80.665074
# 13       20.583259
# 14       83.312063
# 15       74.528425
# 16        8.432155
# 17        7.305670
# 18       83.344403
# 19       82.802787
#    Student_ID Student_Name    English      Maths    Science    History  \
# 0         S01        Alice  96.874050  15.367999  58.682033  59.690510
# 1         S02          Bob   5.462131  81.032680  83.171957  45.664012
# 2         S03      Charlie  60.753099  65.219548  99.323628  24.281512
# 3         S04        David  21.160844  95.052971  35.860852  62.865185
# 4         S05       Edward  63.250994  60.693247   7.020915  60.505272
# 5         S06        Fysal  42.694748  77.348295  37.216613  33.784399
# 6         S07       George  66.276626  46.812190  14.219533  18.582771
# 7         S08       Hareez   5.302984  11.966929  43.980951  54.410098
# 8         S09         Ivan   5.777530  79.508179  94.559212  38.355867
# 9         S10         John  30.968731  14.282925   3.312853  79.916094
# 10        S11       Kelvin  40.219985  55.325651  16.826141   7.462064
# 11        S12          Lia  95.928421  35.789430  95.440164  43.520213
# 12        S13        Maria   8.215446  25.042783  16.518147  36.543154
# 13        S14         Noel  72.833673   7.160086  22.089014  52.867757
# 14        S15       Oliver   5.982402  16.460926  40.977224  80.925749
# 15        S16        Peter  40.694327  91.395888   8.149884  13.852098
# 16        S17          Roy  43.559963  99.270852  13.924531  71.306738
# 17        S18          Ria  30.830802  25.545682  84.271650  78.727155
# 18        S19        Suvin  72.218179  85.284128  32.555060  47.007177
# 19        S20          Tan  18.070264  56.662635   2.618987  14.067349
#
#     Social_Studies
# 0        61.373070
# 1        80.805730
# 2        58.057612
# 3        95.264572
# 4        34.041671
# 5        85.019761
# 6        87.021849
# 7        74.530018
# 8        90.483635
# 9        32.706891
# 10       34.449110
# 11       71.930382
# 12       80.665074
# 13       20.583259
# 14       83.312063
# 15       74.528425
# 16        8.432155
# 17        7.305670
# 18       83.344403
# 19       82.802787

# %%
marks.head()
# Out:
#            Student_Name    English      Maths    Science    History  \
# Student_ID
# S01               Alice  96.874050  15.367999  58.682033  59.690510
# S02                 Bob   5.462131  81.032680  83.171957  45.664012
# S03             Charlie  60.753099  65.219548  99.323628  24.281512
# S04               David  21.160844  95.052971  35.860852  62.865185
# S05              Edward  63.250994  60.693247   7.020915  60.505272
#
#             Social_Studies
# Student_ID
# S01              61.373070
# S02              80.805730
# S03              58.057612
# S04              95.264572
# S05              34.041671

# %%
marks.Student_Name
# Out:
# 0       Alice
# 1         Bob
# 2     Charlie
# 3       David
# 4      Edward
# 5       Fysal
# 6      George
# 7      Hareez
# 8        Ivan
# 9        John
# 10     Kelvin
# 11        Lia
# 12      Maria
# 13       Noel
# 14     Oliver
# 15      Peter
# 16        Roy
# 17        Ria
# 18      Suvin
# 19        Tan
# Name: Student_Name, dtype: object

# %%
display(marks.loc[(marks.Student_Name == 'David')])
# Out:
#   Student_ID Student_Name    English      Maths    Science    History  \
# 3        S04        David  21.160844  95.052971  35.860852  62.865185
#
#    Social_Studies
# 3       95.264572

# %% [markdown]
# # TO DO: Print all records is the Student IS is either S05 or S10

# %%
display(marks.loc[(marks.Student_ID == 'S10') | (marks.Student_ID == 'S05')])
# Out:
#   Student_ID Student_Name    English      Maths   Science    History  \
# 4        S05       Edward  63.250994  60.693247  7.020915  60.505272
# 9        S10         John  30.968731  14.282925  3.312853  79.916094
#
#    Social_Studies
# 4       34.041671
# 9       32.706891

# %% [markdown]
# # TO DO: Fetch all details where marks in English > 70 or marks in Maths > 70.

# %%
display(marks.loc[(marks.English > 70) | (marks.Maths > 70)])
# Out:
#    Student_ID Student_Name    English      Maths    Science    History  \
# 0         S01        Alice  96.874050  15.367999  58.682033  59.690510
# 1         S02          Bob   5.462131  81.032680  83.171957  45.664012
# 3         S04        David  21.160844  95.052971  35.860852  62.865185
# 5         S06        Fysal  42.694748  77.348295  37.216613  33.784399
# 8         S09         Ivan   5.777530  79.508179  94.559212  38.355867
# 11        S12          Lia  95.928421  35.789430  95.440164  43.520213
# 13        S14         Noel  72.833673   7.160086  22.089014  52.867757
# 15        S16        Peter  40.694327  91.395888   8.149884  13.852098
# 16        S17          Roy  43.559963  99.270852  13.924531  71.306738
# 18        S19        Suvin  72.218179  85.284128  32.555060  47.007177
#
#     Social_Studies
# 0        61.373070
# 1        80.805730
# 3        95.264572
# 5        85.019761
# 8        90.483635
# 11       71.930382
# 13       20.583259
# 15       74.528425
# 16        8.432155
# 18       83.344403

# %%
display(marks.loc[(marks.English > 70) & (marks.Maths > 70)])
# Out:
#    Student_ID Student_Name    English      Maths   Science    History  \
# 18        S19        Suvin  72.218179  85.284128  32.55506  47.007177
#
#     Social_Studies
# 18       83.344403

# %%
display(marks.loc[(marks.Student_Name!='Ria')])
# Out:
#    Student_ID Student_Name    English      Maths    Science    History  \
# 0         S01        Alice  96.874050  15.367999  58.682033  59.690510
# 1         S02          Bob   5.462131  81.032680  83.171957  45.664012
# 2         S03      Charlie  60.753099  65.219548  99.323628  24.281512
# 3         S04        David  21.160844  95.052971  35.860852  62.865185
# 4         S05       Edward  63.250994  60.693247   7.020915  60.505272
# 5         S06        Fysal  42.694748  77.348295  37.216613  33.784399
# 6         S07       George  66.276626  46.812190  14.219533  18.582771
# 7         S08       Hareez   5.302984  11.966929  43.980951  54.410098
# 8         S09         Ivan   5.777530  79.508179  94.559212  38.355867
# 9         S10         John  30.968731  14.282925   3.312853  79.916094
# 10        S11       Kelvin  40.219985  55.325651  16.826141   7.462064
# 11        S12          Lia  95.928421  35.789430  95.440164  43.520213
# 12        S13        Maria   8.215446  25.042783  16.518147  36.543154
# 13        S14         Noel  72.833673   7.160086  22.089014  52.867757
# 14        S15       Oliver   5.982402  16.460926  40.977224  80.925749
# 15        S16        Peter  40.694327  91.395888   8.149884  13.852098
# 16        S17          Roy  43.559963  99.270852  13.924531  71.306738
# 18        S19        Suvin  72.218179  85.284128  32.555060  47.007177
# 19        S20          Tan  18.070264  56.662635   2.618987  14.067349
#
#     Social_Studies
# 0        61.373070
# 1        80.805730
# 2        58.057612
# 3        95.264572
# 4        34.041671
# 5        85.019761
# 6        87.021849
# 7        74.530018
# 8        90.483635
# 9        32.706891
# 10       34.449110
# 11       71.930382
# 12       80.665074
# 13       20.583259
# 14       83.312063
# 15       74.528425
# 16        8.432155
# 18       83.344403
# 19       82.802787

# %%
marks = pd.read_csv('marks.csv', index_col='Student_ID')  # could have given the index no. of the columns (0,1..) as well.
display(marks)
# Out:
#            Student_Name    English      Maths    Science    History  \
# Student_ID
# S01               Alice  96.874050  15.367999  58.682033  59.690510
# S02                 Bob   5.462131  81.032680  83.171957  45.664012
# S03             Charlie  60.753099  65.219548  99.323628  24.281512
# S04               David  21.160844  95.052971  35.860852  62.865185
# S05              Edward  63.250994  60.693247   7.020915  60.505272
# S06               Fysal  42.694748  77.348295  37.216613  33.784399
# S07              George  66.276626  46.812190  14.219533  18.582771
# S08              Hareez   5.302984  11.966929  43.980951  54.410098
# S09                Ivan   5.777530  79.508179  94.559212  38.355867
# S10                John  30.968731  14.282925   3.312853  79.916094
# S11              Kelvin  40.219985  55.325651  16.826141   7.462064
# S12                 Lia  95.928421  35.789430  95.440164  43.520213
# S13               Maria   8.215446  25.042783  16.518147  36.543154
# S14                Noel  72.833673   7.160086  22.089014  52.867757
# S15              Oliver   5.982402  16.460926  40.977224  80.925749
# S16               Peter  40.694327  91.395888   8.149884  13.852098
# S17                 Roy  43.559963  99.270852  13.924531  71.306738
# S18                 Ria  30.830802  25.545682  84.271650  78.727155
# S19               Suvin  72.218179  85.284128  32.555060  47.007177
# S20                 Tan  18.070264  56.662635   2.618987  14.067349
#
#             Social_Studies
# Student_ID
# S01              61.373070
# S02              80.805730
# S03              58.057612
# S04              95.264572
# S05              34.041671
# S06              85.019761
# S07              87.021849
# S08              74.530018
# S09              90.483635
# S10              32.706891
# S11              34.449110
# S12              71.930382
# S13              80.665074
# S14              20.583259
# S15              83.312063
# S16              74.528425
# S17               8.432155
# S18               7.305670
# S19              83.344403
# S20              82.802787

# %%
display(marks.iloc[3])
# Out:
# Student_Name          David
# English           21.160844
# Maths             95.052971
# Science           35.860852
# History           62.865185
# Social_Studies    95.264572
# Name: S04, dtype: object

# %%
iloc is related to the index of the row not a string.

# %%
display(marks.iloc[[0, 4]])
# Out:
#            Student_Name    English      Maths    Science    History  \
# Student_ID
# S01               Alice  96.874050  15.367999  58.682033  59.690510
# S05              Edward  63.250994  60.693247   7.020915  60.505272
#
#             Social_Studies
# Student_ID
# S01              61.373070
# S05              34.041671

# %% [markdown]
# # TO DO: Print the details from 0th, 5th and 8th rows, along with the details of indices 4th, 11th and 16th.

# %%
display(marks.iloc[4],marks.iloc[11],marks.iloc[16])
# Out:
# Student_Name         Edward
# English           63.250994
# Maths             60.693247
# Science            7.020915
# History           60.505272
# Social_Studies    34.041671
# Name: S05, dtype: object
# Student_Name            Lia
# English           95.928421
# Maths              35.78943
# Science           95.440164
# History           43.520213
# Social_Studies    71.930382
# Name: S12, dtype: object
# Student_Name            Roy
# English           43.559963
# Maths             99.270852
# Science           13.924531
# History           71.306738
# Social_Studies     8.432155
# Name: S17, dtype: object

# %%
display(marks.iloc[[0, 4,7]])
# Out:
#            Student_Name    English      Maths    Science    History  \
# Student_ID
# S01               Alice  96.874050  15.367999  58.682033  59.690510
# S05              Edward  63.250994  60.693247   7.020915  60.505272
# S08              Hareez   5.302984  11.966929  43.980951  54.410098
#
#             Social_Studies
# Student_ID
# S01              61.373070
# S05              34.041671
# S08              74.530018

# %%
display(marks.loc['S01':'S05'])
# Out:
#            Student_Name    English      Maths    Science    History  \
# Student_ID
# S01               Alice  96.874050  15.367999  58.682033  59.690510
# S02                 Bob   5.462131  81.032680  83.171957  45.664012
# S03             Charlie  60.753099  65.219548  99.323628  24.281512
# S04               David  21.160844  95.052971  35.860852  62.865185
# S05              Edward  63.250994  60.693247   7.020915  60.505272
#
#             Social_Studies
# Student_ID
# S01              61.373070
# S02              80.805730
# S03              58.057612
# S04              95.264572
# S05              34.041671

# %% [markdown]
# # TO DO: Copy paste the above codes and explain the output for each syntax as comments as per given example.
# # Example: display(marks.iloc[[3:5]])  # Prints all values from all columns for indices 2, 3 and 4.

# %%
display(marks.iloc[[2:5]])
# Out:
#   File "<ipython-input-254-5f3034473666>", line 1
#     display(marks.iloc[[2:5]])
#                          ^
# SyntaxError: invalid syntax

# %%
display(marks.iloc[[0:5]])
# Out:
#   File "<ipython-input-255-dc4a1a0ac622>", line 1
#     display(marks.iloc[[0:5]])
#                          ^
# SyntaxError: invalid syntax

# %%
display(marks.iloc[[:5]])
# Out:
#   File "<ipython-input-256-6d77d6e23672>", line 1
#     display(marks.iloc[[:5]])
#                         ^
# SyntaxError: invalid syntax

# %%
isplay(marks.iloc[[15:20]])
# Out:
#   File "<ipython-input-257-2ac0bae90145>", line 1
#     isplay(marks.iloc[[15:20]])
#                          ^
# SyntaxError: invalid syntax

# %%
temps = pd.DataFrame({"sequence":[1,2,3,4,5],
          "measurement_type":['actual','actual','actual',None,'estimated'],  # With strings, it will become 'None'
          "temperature_f":[67.24,84.56,91.61,None,49.64]   #With numbers, it will become 'NaN'
         })
temps
# Out:
#    sequence measurement_type  temperature_f
# 0         1           actual          67.24
# 1         2           actual          84.56
# 2         3           actual          91.61
# 3         4             None            NaN
# 4         5        estimated          49.64

# %%
temps.isna()
# Out:
#    sequence  measurement_type  temperature_f
# 0     False             False          False
# 1     False             False          False
# 2     False             False          False
# 3     False              True           True
# 4     False             False          False

# %%
temps.isna().sum()
# Out:
# sequence            0
# measurement_type    1
# temperature_f       1
# dtype: int64

# %%
temps.isna().sum().sum()
# Out:
# 2

# %%
clean_temps = temps.dropna(how='any')  # how: {'any', 'all'}. Default 'any'
display (clean_temps)
# Out:
#    sequence measurement_type  temperature_f
# 0         1           actual          67.24
# 1         2           actual          84.56
# 2         3           actual          91.61
# 4         5        estimated          49.64

# %% [markdown]
# # TO DO:  Copy paste the codes from the above cell, change the 'how' argument as 'all' and observe the difference in output.

# %%
clean_temps = temps.dropna(how='all')  
display (clean_temps)
# Out:
#    sequence measurement_type  temperature_f
# 0         1           actual          67.24
# 1         2           actual          84.56
# 2         3           actual          91.61
# 3         4             None            NaN
# 4         5        estimated          49.64

# %% [markdown]
# Displays rows where not all values are null hence the rows didnt get dropped

# %%
temps.dropna()
# Out:
#    sequence measurement_type  temperature_f
# 0         1           actual          67.24
# 1         2           actual          84.56
# 2         3           actual          91.61
# 4         5        estimated          49.64

# %%
temps.dropna(axis = 'columns')
# Out:
#    sequence
# 0         1
# 1         2
# 2         3
# 3         4
# 4         5

# %%
temps['temperature_f'].cumsum()   # Returns the commulative sum. 

# It will skip null values. skipna = TRUE by default
# Out:
# 0     67.24
# 1    151.80
# 2    243.41
# 3       NaN
# 4    293.05
# Name: temperature_f, dtype: float64

# %%
temps['temperature_f'].cumsum(skipna=False)
# Out:
# 0     67.24
# 1    151.80
# 2    243.41
# 3       NaN
# 4       NaN
# Name: temperature_f, dtype: float64

# %%
temps.fillna(value=0, inplace = True)   # Do you remember the use of inplace? If not, please scroll up and check.
display(temps)
# Out:
#    sequence measurement_type  temperature_f
# 0         1           actual          67.24
# 1         2           actual          84.56
# 2         3           actual          91.61
# 3         4                0           0.00
# 4         5        estimated          49.64

# %%
temps
# Out:
#    sequence measurement_type  temperature_f
# 0         1           actual          67.24
# 1         2           actual          84.56
# 2         3           actual          91.61
# 3         4                0           0.00
# 4         5        estimated          49.64

# %% [markdown]
# 0 in measurement type is an integer while in temeparture_f it is a float type

# %%
temps['temperature_f'].cumsum()   # Returns the commulative sum. 

# It will skip null values. skipna = TRUE by default

# CAN YOU THINK OF ANY PRACTICAL USE OF cumsum() ?
# Out:
# 0     67.24
# 1    151.80
# 2    243.41
# 3    243.41
# 4    293.05
# Name: temperature_f, dtype: float64

# %%
temps['temperature_f'].cumsum(skipna=False)
# Out:
# 0     67.24
# 1    151.80
# 2    243.41
# 3    243.41
# 4    293.05
# Name: temperature_f, dtype: float64

# %%
# fill missing value with zero
temps.fillna(value=0, inplace = True)   # Do you remember the use of inplace? If not, please scroll up and check.
display(temps)
# Out:
#    sequence measurement_type  temperature_f
# 0         1           actual          67.24
# 1         2           actual          84.56
# 2         3           actual          91.61
# 3         4                0           0.00
# 4         5        estimated          49.64

# %%
temps = pd.DataFrame({"sequence":[1,2,3,4,5],
          "measurement_type":['actual','actual','actual',None,'estimated'],
          "temperature_f":[67.24,84.56,91.61,None,49.64]
         })
temps.fillna(method='pad' , inplace=True)  # 'pad' means padding. Take value from previous row
temps
# Out:
#    sequence measurement_type  temperature_f
# 0         1           actual          67.24
# 1         2           actual          84.56
# 2         3           actual          91.61
# 3         4           actual          91.61
# 4         5        estimated          49.64

# %%
temps1 = pd.DataFrame({"sequence":[1,2,3,4,5],
          "measurement_type":['actual','actual','actual',None,'estimated'],
          "temperature_f":[67.24,84.56,91.61,None,49.64]
         })
temps1.fillna(method='bfill' , inplace=True)  # bfill takes next value to replace
temps1
# Out:
#    sequence measurement_type  temperature_f
# 0         1           actual          67.24
# 1         2           actual          84.56
# 2         3           actual          91.61
# 3         4        estimated          49.64
# 4         5        estimated          49.64

# %%
# fill missing value with mean
temps = pd.DataFrame({"sequence":[1,2,3,4,5],
          "measurement_type":['actual','actual','actual',None,'estimated'],
          "temperature_f":[67.24,84.56,91.61,None,49.64]
         })
temps['temperature_f'].fillna(temps['temperature_f'].mean(), inplace=True)  # Mean will not work on strings
temps
# Out:
#    sequence measurement_type  temperature_f
# 0         1           actual        67.2400
# 1         2           actual        84.5600
# 2         3           actual        91.6100
# 3         4             None        73.2625
# 4         5        estimated        49.6400

# %%
# lambda is used to define a temporary expression without any return statement. It always contains an expression
# that is returned. There is no need to assign a variable with lambda.


def cube(y):
    return y*y*y  # return is a keyword. Python stops when the code reaches to return statement. Print is a function.
    

# using the normally defined function
    print(cube(5))
 
# using the lambda function                 # Why this is red? How to resolve it?
lambda_cube = lambda y: y*y*y
print(lambda_cube(5))
# Out:
# 125

# %%
# Creating new dataframe to explore the use of Lambda and changing indices.

teams = pd.DataFrame({"Region":['North','West','East','South'],
          "Team":['One','Two','One','Two'],
          "Squad":['A','B','C','D'],
          "Revenue":[7500,5500,2750,6400],
            "Cost":[5200,5100,4400,5300]})

display (teams)
# Out:
#   Region Team Squad  Revenue  Cost
# 0  North  One     A     7500  5200
# 1   West  Two     B     5500  5100
# 2   East  One     C     2750  4400
# 3  South  Two     D     6400  5300

# %%
# apply() to alter values along an axis in your dataframe or in a series/column 

# Categorise based on the revenue and cost
teams['Profit'] = teams.apply(lambda x: 'Profit' if x['Revenue']>x['Cost'] else 'Loss',axis=1)
teams
# Out:
#   Region Team Squad  Revenue  Cost  Profit
# 0  North  One     A     7500  5200  Profit
# 1   West  Two     B     5500  5100  Profit
# 2   East  One     C     2750  4400    Loss
# 3  South  Two     D     6400  5300  Profit

# %%
# Use map() to substitute each value in a series
team_map = {"One":"Red","Two":"Blue"}      # new variable - dictionary (key-value pair)
teams['Team Color'] = teams['Team'].map(team_map) # A new column with mapped values
teams
# Out:
#   Region Team Squad  Revenue  Cost  Profit Team Color
# 0  North  One     A     7500  5200  Profit        Red
# 1   West  Two     B     5500  5100  Profit       Blue
# 2   East  One     C     2750  4400    Loss        Red
# 3  South  Two     D     6400  5300  Profit       Blue

# %%
# applymap() method do elementwise operation on the entire dataframe.
# This method applies a function that accepts and returns a scalar to every element of a DataFrame.

teams.applymap(lambda x: len(str(x)))  # int(x) won't work because data has strings which can not be convereted to int.
# Out:
#    Region  Team  Squad  Revenue  Cost  Profit  Team Color
# 0       5     3      1        4     4       6           3
# 1       4     3      1        4     4       6           4
# 2       4     3      1        4     4       4           3
# 3       5     3      1        4     4       6           4

# %%
# Grouping on different categories. Needs the category as well as parameter
teams.groupby(['Profit']).max()
# Out:
#        Region Team Squad  Revenue  Cost Team Color
# Profit
# Loss     East  One     C     2750  4400        Red
# Profit   West  Two     D     7500  5300        Red

# %%
# TO DO: Can you group the records on Cost with minimum values?
teams.groupby(['Cost']).min()
# Out:
#      Region Team Squad  Revenue  Profit Team Color
# Cost
# 4400   East  One     C     2750    Loss        Red
# 5100   West  Two     B     5500  Profit       Blue
# 5200  North  One     A     7500  Profit        Red
# 5300  South  Two     D     6400  Profit       Blue

# %%
teams.groupby(['Revenue']).mean()
# Out:
#          Cost
# Revenue
# 2750     4400
# 5500     5100
# 6400     5300
# 7500     5200

# %%
teams.groupby(['Team']).agg({'Revenue':['mean','min','max']})
# Out:
#      Revenue
#         mean   min   max
# Team
# One     5125  2750  7500
# Two     5950  5500  6400

# %%
teams.head()
# Out:
#   Region Team Squad  Revenue  Cost  Profit Team Color
# 0  North  One     A     7500  5200  Profit        Red
# 1   West  Two     B     5500  5100  Profit       Blue
# 2   East  One     C     2750  4400    Loss        Red
# 3  South  Two     D     6400  5300  Profit       Blue

# %%
teams.groupby(['Team']),
# Out:
#      Region Squad  Revenue  Cost  Profit Team Color
# Team
# One    East     A     2750  4400    Loss        Red
# Two   South     B     5500  5100  Profit       Blue

# %%
team_map = {"One":"Red","Two":"Blue"}      # new variable - dictionary (key-value pair)
teams['Team Color'] = teams['Team'].map(team_map) # A new column with mapped values
teams
# Out:
#   Region Team Squad  Revenue  Cost  Profit Team Color
# 0  North  One     A     7500  5200  Profit        Red
# 1   West  Two     B     5500  5100  Profit       Blue
# 2   East  One     C     2750  4400    Loss        Red
# 3  South  Two     D     6400  5300  Profit       Blue

# %%
teams_index = teams.set_index(['Team'])

# %%
teams_index
# Out:
#      Region Squad  Revenue  Cost  Profit Team Color
# Team
# One   North     A     7500  5200  Profit        Red
# Two    West     B     5500  5100  Profit       Blue
# One    East     C     2750  4400    Loss        Red
# Two   South     D     6400  5300  Profit       Blue

# %%
teams_reindex = teams.set_index(['Region','Team'])  # 2 indices. useful when values are not unique
display(teams)

print()    # TO print blank/new line.


display(teams_reindex)
# Out:
#   Region Team Squad  Revenue  Cost  Profit Team Color
# 0  North  One     A     7500  5200  Profit        Red
# 1   West  Two     B     5500  5100  Profit       Blue
# 2   East  One     C     2750  4400    Loss        Red
# 3  South  Two     D     6400  5300  Profit       Blue
#             Squad  Revenue  Cost  Profit Team Color
# Region Team
# North  One      A     7500  5200  Profit        Red
# West   Two      B     5500  5100  Profit       Blue
# East   One      C     2750  4400    Loss        Red
# South  Two      D     6400  5300  Profit       Blue

# %%
stacked = pd.DataFrame(teams_reindex.stack())
stacked
# Out:
#                              0
# Region Team
# North  One  Squad            A
#             Revenue       7500
#             Cost          5200
#             Profit      Profit
#             Team Color     Red
# West   Two  Squad            B
#             Revenue       5500
#             Cost          5100
#             Profit      Profit
#             Team Color    Blue
# East   One  Squad            C
#             Revenue       2750
#             Cost          4400
#             Profit        Loss
#             Team Color     Red
# South  Two  Squad            D
#             Revenue       6400
#             Cost          5300
#             Profit      Profit
#             Team Color    Blue

# %%
# Defining two new dataframes
group1 = pd.DataFrame({'name': ['Alice', 'Bob', 'Charlie', 'David'],
                    'number': [1, 2, 3, 4]})
group2 = pd.DataFrame({'name': ['Charlie', 'David', 'Edward', 'Ford'],
                    'number': [3, 4, 5, 6]})

# %%
group1.merge(group2,how='left', on='number')   # Left - all from 1st table and only common from 2nd table.

# Notice the NAN or empty values.
# Out:
#     name_x  number   name_y
# 0    Alice       1      NaN
# 1      Bob       2      NaN
# 2  Charlie       3  Charlie
# 3    David       4    David

# %%
group1.merge(group2)   # Shows only the common records.
# Out:
#       name  number
# 0  Charlie       3
# 1    David       4

# %%
group1.merge(group2,how='inner',left_on='number',right_on='number')  # Inner - Shows only the common records

# Why there are no null values now in the output? Answer as a comment.
# Out:
#     name_x  number   name_y
# 0  Charlie       3  Charlie
# 1    David       4    David

# %% [markdown]
# We have done an inner join therfore only the matching records in both tables will be displayed

# %%
group1.merge(group2,how='right',left_on='number',right_on='number')
# Out:
#     name_x  number   name_y
# 0  Charlie       3  Charlie
# 1    David       4    David
# 2      NaN       5   Edward
# 3      NaN       6     Ford

# %%
mtcars=pd.read_csv('mtcars.csv')

# %%
mtcars.head()
# Out:
#            car_names   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2

# %%
import seaborn as sns

# %%
# TO DO : Create a scatter plot with mpg and hp by providing xlabel and ylabel
sns.scatterplot(x='mpg',y='hp',data=mtcars)

# %%
# TO DO: Change the color to red in the previous code
sns.scatterplot(x='mpg',y='hp',data=mtcars,color='red')

# %%
TO DO: Create crosstab for cyl(cylinder) and columns as count

# A cross-tabulation (or crosstab) is a two- (or more) dimensional table that records the number (frequency) of 
# respondents that have the specific characteristics described in the cells of the table.

# %%
counts = mtcars.apply(pd.value_counts)

# %%
counts = mtcars.apply(pd.value_counts).fillna(0)

# %%
# TO DO: Create groupby (cyl) to visualize mpg and hp in a bar chart
# Hint: Use nunique()

# %%
mtcars.groupby('cyl')['mpg','hp'].nunique().plot(kind='bar')
# Out:
# /Users/shreya/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.

# %%
# TO DO: Create a pie chart for cyl count
plt.pie(mtcars.cyl.value_counts(),labels=[4,6,8])
# Out:
# ([<matplotlib.patches.Wedge at 0x164fe43d0>,
#   <matplotlib.patches.Wedge at 0x164fc2a90>,
#   <matplotlib.patches.Wedge at 0x164fe4e10>],
#  [Text(0.21459935421774115, 1.0788638084435536, '4'),
#   Text(-0.8503114986990109, -0.6978326125800098, '6'),
#   Text(0.8503114986990103, -0.6978326125800106, '8')])

# %%
# TO DO: Create a Histogram for MPG column
# Reading: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.plot.hist.html

# %%
plt.hist(mtcars.mpg,bins=5,color='green')
# Out:
# (array([ 6., 12.,  8.,  2.,  4.]),
#  array([10.4, 15.1, 19.8, 24.5, 29.2, 33.9]),
#  <a list of 5 Patch objects>)
